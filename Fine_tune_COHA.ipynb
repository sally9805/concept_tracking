# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/concept_tracking/concept_tracking
# Out:
# /content/gdrive/My Drive/concept_tracking/concept_tracking

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install 🤗 Transformers and 🤗 Datasets. Uncomment the following cell and run it.

# %%
! pip install datasets transformers
# Out:
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, datasets
# Successfully installed datasets-2.16.1 dill-0.3.7 multiprocess-0.70.15

# %%
! pip install -U accelerate
! pip install -U transformers
# Out:
# Collecting accelerate
#   Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.26.1
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting transformers
#   Downloading transformers-4.37.0-py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed transformers-4.37.0

# %% [markdown]
# If you're opening this notebook locally, make sure your environment has an install from the last version of those libraries.
#
# To be able to share your model with the community and generate results like the one shown in the picture below via the inference API, there are a few more steps to follow.
#
# First you have to store your authentication token from the Hugging Face website (sign up [here](https://huggingface.co/join) if you haven't already!) then execute the following cell and input your username and password:

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# Then you need to install Git-LFS. Uncomment the following instructions:

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %% [markdown]
# Make sure your version of Transformers is at least 4.11.0 since the functionality was introduced in that version:

# %%
import accelerate
import transformers

transformers.__version__, accelerate.__version__
# Out:
# ('4.37.0', '0.26.1')

# %% [markdown]
# You can find a script version of this notebook to fine-tune your model in a distributed fashion using multiple GPUs or TPUs [here](https://github.com/huggingface/transformers/tree/master/examples/language-modeling).

# %% [markdown]
# We also quickly upload some telemetry - this tells us which examples and software versions are getting used so we know where to prioritize our maintenance efforts. We don't collect (or care about) any personally identifiable information, but if you'd prefer not to be counted, feel free to skip this step or delete this cell entirely.

# %%
from transformers.utils import send_example_telemetry

send_example_telemetry("language_modeling_notebook", framework="pytorch")

# %% [markdown]
# # Fine-tuning a language model

# %% [markdown]
# In this notebook, we'll see how to fine-tune one of the [🤗 Transformers](https://github.com/huggingface/transformers) model on a language modeling tasks. We will cover two types of language modeling tasks which are:
#
# - Causal language modeling: the model has to predict the next token in the sentence (so the labels are the same as the inputs shifted to the right). To make sure the model does not cheat, it gets an attention mask that will prevent it to access the tokens after token i when trying to predict the token i+1 in the sentence.
#
# ![Widget inference representing the causal language modeling task](https://github.com/huggingface/notebooks/blob/master/examples/images/causal_language_modeling.png?raw=1)
#
# - Masked language modeling: the model has to predict some tokens that are masked in the input. It still has access to the whole sentence, so it can use the tokens before and after the tokens masked to predict their value.
#
# ![Widget inference representing the masked language modeling task](https://github.com/huggingface/notebooks/blob/master/examples/images/masked_language_modeling.png?raw=1)
#
# We will see how to easily load and preprocess the dataset for each one of those tasks, and how to use the `Trainer` API to fine-tune a model on it.
#
# A script version of this notebook you can directly run on a distributed environment or on TPU is available in our [examples folder](https://github.com/huggingface/transformers/tree/master/examples).

# %% [markdown]
# ## Preparing the dataset

# %% [markdown]
# For each of those tasks, we will use the [Wikitext 2]() dataset as an example. You can load it very easily with the 🤗 Datasets library.

# %%
# from datasets import load_dataset
# datasets = load_dataset('wikitext', 'wikitext-2-raw-v1')

# %%
# !unzip "/content/gdrive/My Drive/coha/1900s.zip" -d "/content"
# Out:
# Archive:  /content/gdrive/My Drive/coha/1900s.zip
#    creating: /content/1900s/
#   inflating: /content/1900s/mag_1905_474089.txt
#   inflating: /content/1900s/mag_1909_486714.txt
#   inflating: /content/1900s/news_1908_678106.txt
#   inflating: /content/1900s/mag_1902_473583.txt
#   inflating: /content/1900s/mag_1902_473597.txt
#   inflating: /content/1900s/mag_1908_474840.txt
#   inflating: /content/1900s/mag_1908_474698.txt
#   inflating: /content/1900s/news_1906_677199.txt
#   inflating: /content/1900s/mag_1903_473699.txt
#   inflating: /content/1900s/mag_1909_486728.txt
#   inflating: /content/1900s/mag_1905_430191.txt
#   inflating: /content/1900s/news_1909_678552.txt
#   inflating: /content/1900s/mag_1905_430185.txt
#   inflating: /content/1900s/news_1906_781141.txt
#   inflating: /content/1900s/nf_1900_754813.txt
#   inflating: /content/1900s/fic_1907_14314.txt
#   inflating: /content/1900s/news_1902_676205.txt
#   inflating: /content/1900s/fic_1908_2907.txt
#   inflating: /content/1900s/news_1905_676935.txt
#   inflating: /content/1900s/mag_1901_486504.txt
#   inflating: /content/1900s/mag_1901_486510.txt
#   inflating: /content/1900s/news_1907_677532.txt
#   inflating: /content/1900s/news_1905_676909.txt
#   inflating: /content/1900s/mag_1905_430152.txt
#   inflating: /content/1900s/mag_1904_439278.txt
#   inflating: /content/1900s/news_1909_678591.txt
#   inflating: /content/1900s/mag_1905_486592.txt
#   inflating: /content/1900s/news_1903_676321.txt
#   inflating: /content/1900s/news_1908_678304.txt
#   inflating: /content/1900s/nf_1900_774057.txt
#   inflating: /content/1900s/fic_1900_13184.txt
#   inflating: /content/1900s/news_1908_678310.txt
#   inflating: /content/1900s/fic_1909_3833.txt
#   inflating: /content/1900s/news_1903_676335.txt
#   inflating: /content/1900s/news_1904_676636.txt
#   inflating: /content/1900s/news_1906_781357.txt
#   inflating: /content/1900s/news_1905_677168.txt
#   inflating: /content/1900s/nf_1909_773801.txt
#   inflating: /content/1900s/nf_1909_773815.txt
#   inflating: /content/1900s/news_1900_675430.txt
#   inflating: /content/1900s/mag_1907_438183.txt
#   inflating: /content/1900s/fic_1901_14515.txt
#   inflating: /content/1900s/news_1907_677730.txt
#   inflating: /content/1900s/news_1900_675424.txt
#   inflating: /content/1900s/news_1904_676805.txt
#   inflating: /content/1900s/news_1906_677370.txt
#   inflating: /content/1900s/news_1908_677976.txt
#   inflating: /content/1900s/news_1909_781450.txt
#   inflating: /content/1900s/news_1901_675851.txt
#   inflating: /content/1900s/mag_1901_473348.txt
#   inflating: /content/1900s/mag_1908_438082.txt
#   inflating: /content/1900s/news_1900_675593.txt
#   inflating: /content/1900s/news_1907_677687.txt
#   inflating: /content/1900s/news_1908_678264.txt
#   inflating: /content/1900s/news_1904_676742.txt
#   inflating: /content/1900s/mag_1904_473952.txt
#   inflating: /content/1900s/news_1905_677034.txt
#   inflating: /content/1900s/news_1909_678624.txt
#   inflating: /content/1900s/mag_1907_430332.txt
#   inflating: /content/1900s/mag_1908_430384.txt
#   inflating: /content/1900s/fic_1904_4337.txt
#   inflating: /content/1900s/news_1907_677877.txt
#   inflating: /content/1900s/mag_1902_430082.txt
#   inflating: /content/1900s/news_1907_677863.txt
#   inflating: /content/1900s/news_1902_676173.txt
#   inflating: /content/1900s/mag_1907_430326.txt
#   inflating: /content/1900s/news_1901_675879.txt
#   inflating: /content/1900s/mag_1908_430390.txt
#   inflating: /content/1900s/news_1909_678630.txt
#   inflating: /content/1900s/mag_1905_430218.txt
#   inflating: /content/1900s/news_1900_675544.txt
#   inflating: /content/1900s/mag_1908_438041.txt
#   inflating: /content/1900s/mag_1902_430069.txt
#   inflating: /content/1900s/nf_1909_774029.txt
#   inflating: /content/1900s/news_1904_676781.txt
#   inflating: /content/1900s/mag_1908_430347.txt
#   inflating: /content/1900s/mag_1905_486828.txt
#   inflating: /content/1900s/mag_1905_430224.txt
#   inflating: /content/1900s/mag_1900_485049.txt
#   inflating: /content/1900s/mag_1909_437726.txt
#   inflating: /content/1900s/mag_1902_430055.txt
#   inflating: /content/1900s/mag_1905_430230.txt
#   inflating: /content/1900s/mag_1908_430353.txt
#   inflating: /content/1900s/news_1901_675662.txt
#   inflating: /content/1900s/news_1907_677491.txt
#   inflating: /content/1900s/mag_1906_474440.txt
#   inflating: /content/1900s/fic_1905_2578.txt
#   inflating: /content/1900s/mag_1902_440029.txt
#   inflating: /content/1900s/news_1908_678066.txt
#   inflating: /content/1900s/news_1907_677485.txt
#   inflating: /content/1900s/news_1909_678368.txt
#   inflating: /content/1900s/news_1907_781307.txt
#   inflating: /content/1900s/mag_1902_486654.txt
#   inflating: /content/1900s/news_1909_678354.txt
#   inflating: /content/1900s/news_1907_677452.txt
#   inflating: /content/1900s/mag_1902_473434.txt
#   inflating: /content/1900s/news_1904_676597.txt
#   inflating: /content/1900s/news_1904_676583.txt
#   inflating: /content/1900s/news_1908_781372.txt
#   inflating: /content/1900s/news_1907_677446.txt
#   inflating: /content/1900s/mag_1903_473706.txt
#   inflating: /content/1900s/news_1908_781428.txt
#   inflating: /content/1900s/news_1908_678099.txt
#   inflating: /content/1900s/news_1909_678397.txt
#   inflating: /content/1900s/mag_1909_437530.txt
#   inflating: /content/1900s/news_1908_781429.txt
#   inflating: /content/1900s/news_1909_678382.txt
#   inflating: /content/1900s/fic_1909_4230.txt
#   inflating: /content/1900s/news_1904_676582.txt
#   inflating: /content/1900s/mag_1902_473421.txt
#   inflating: /content/1900s/news_1907_677453.txt
#   inflating: /content/1900s/news_1908_781367.txt
#   inflating: /content/1900s/news_1904_676596.txt
#   inflating: /content/1900s/news_1909_678433.txt
#   inflating: /content/1900s/mag_1902_486641.txt
#   inflating: /content/1900s/mag_1906_438677.txt
#   inflating: /content/1900s/mag_1902_486655.txt
#   inflating: /content/1900s/news_1908_678067.txt
#   inflating: /content/1900s/mag_1907_438223.txt
#   inflating: /content/1900s/news_1907_677490.txt
#   inflating: /content/1900s/news_1907_677679.txt
#   inflating: /content/1900s/mag_1902_430054.txt
#   inflating: /content/1900s/news_1901_675663.txt
#   inflating: /content/1900s/mag_1908_430352.txt
#   inflating: /content/1900s/mag_1905_430231.txt
#   inflating: /content/1900s/nf_1905_773516.txt
#   inflating: /content/1900s/mag_1905_430225.txt
#   inflating: /content/1900s/news_1904_780994.txt
#   inflating: /content/1900s/news_1900_675579.txt
#   inflating: /content/1900s/news_1906_677205.txt
#   inflating: /content/1900s/mag_1902_430068.txt
#   inflating: /content/1900s/news_1903_676283.txt
#   inflating: /content/1900s/news_1901_675887.txt
#   inflating: /content/1900s/mag_1905_486815.txt
#   inflating: /content/1900s/news_1901_675893.txt
#   inflating: /content/1900s/mag_1905_430219.txt
#   inflating: /content/1900s/news_1902_676199.txt
#   inflating: /content/1900s/news_1900_675545.txt
#   inflating: /content/1900s/news_1907_677862.txt
#   inflating: /content/1900s/mag_1908_430391.txt
#   inflating: /content/1900s/mag_1907_430327.txt
#   inflating: /content/1900s/news_1905_677009.txt
#   inflating: /content/1900s/mag_1908_430385.txt
#   inflating: /content/1900s/mag_1907_430333.txt
#   inflating: /content/1900s/news_1909_678625.txt
#   inflating: /content/1900s/mag_1902_430083.txt
#   inflating: /content/1900s/news_1907_677876.txt
#   inflating: /content/1900s/news_1902_676166.txt
#   inflating: /content/1900s/news_1907_677686.txt
#   inflating: /content/1900s/mag_1908_438097.txt
#   inflating: /content/1900s/news_1904_676743.txt
#   inflating: /content/1900s/news_1901_675844.txt
#   inflating: /content/1900s/mag_1907_486903.txt
#   inflating: /content/1900s/news_1901_675688.txt
#   inflating: /content/1900s/news_1905_677021.txt
#   inflating: /content/1900s/news_1904_676757.txt
#   inflating: /content/1900s/news_1903_676532.txt
#   inflating: /content/1900s/news_1906_677365.txt
#   inflating: /content/1900s/news_1901_675717.txt
#   inflating: /content/1900s/news_1906_677403.txt
#   inflating: /content/1900s/news_1901_675703.txt
#   inflating: /content/1900s/news_1904_676804.txt
#   inflating: /content/1900s/fic_1902_12409.txt
#   inflating: /content/1900s/news_1908_677977.txt
#   inflating: /content/1900s/news_1906_677371.txt
#   inflating: /content/1900s/news_1903_676491.txt
#   inflating: /content/1900s/news_1907_677725.txt
#   inflating: /content/1900s/mag_1907_438182.txt
#   inflating: /content/1900s/news_1906_781356.txt
#   inflating: /content/1900s/news_1904_676637.txt
#   inflating: /content/1900s/fic_1904_3263.txt
#   inflating: /content/1900s/news_1908_678305.txt
#   inflating: /content/1900s/news_1905_677155.txt
#   inflating: /content/1900s/news_1909_678584.txt
#   inflating: /content/1900s/nf_1905_773660.txt
#   inflating: /content/1900s/mag_1909_465303.txt
#   inflating: /content/1900s/mag_1901_440378.txt
#   inflating: /content/1900s/news_1906_677173.txt
#   inflating: /content/1900s/news_1909_678590.txt
#   inflating: /content/1900s/mag_1905_430153.txt
#   inflating: /content/1900s/news_1907_677533.txt
#   inflating: /content/1900s/news_1907_677527.txt
#   inflating: /content/1900s/mag_1901_486505.txt
#   inflating: /content/1900s/mag_1901_440436.txt
#   inflating: /content/1900s/mag_1908_437950.txt
#   inflating: /content/1900s/mag_1905_430184.txt
#   inflating: /content/1900s/mag_1909_486729.txt
#   inflating: /content/1900s/mag_1905_430190.txt
#   inflating: /content/1900s/news_1908_678113.txt
#   inflating: /content/1900s/mag_1903_486407.txt
#   inflating: /content/1900s/mag_1901_440387.txt
#   inflating: /content/1900s/news_1906_677198.txt
#   inflating: /content/1900s/mag_1909_486715.txt
#   inflating: /content/1900s/mag_1901_440393.txt
#   inflating: /content/1900s/fic_1904_3713.txt
#   inflating: /content/1900s/mag_1903_486413.txt
#   inflating: /content/1900s/news_1908_678107.txt
#   inflating: /content/1900s/mag_1901_440385.txt
#   inflating: /content/1900s/news_1908_678111.txt
#   inflating: /content/1900s/news_1908_678105.txt
#   inflating: /content/1900s/mag_1905_430186.txt
#   inflating: /content/1900s/news_1906_781142.txt
#   inflating: /content/1900s/mag_1905_430192.txt
#   inflating: /content/1900s/news_1908_678139.txt
#   inflating: /content/1900s/news_1902_676212.txt
#   inflating: /content/1900s/mag_1906_438715.txt
#   inflating: /content/1900s/mag_1905_430179.txt
#   inflating: /content/1900s/news_1907_677525.txt
#   inflating: /content/1900s/mag_1908_437991.txt
#   inflating: /content/1900s/mag_1908_474664.txt
#   inflating: /content/1900s/news_1909_678586.txt
#   inflating: /content/1900s/mag_1905_430151.txt
#   inflating: /content/1900s/mag_1901_440408.txt
#   inflating: /content/1900s/news_1908_678313.txt
#   inflating: /content/1900s/news_1905_677143.txt
#   inflating: /content/1900s/mag_1900_430008.txt
#   inflating: /content/1900s/news_1906_677398.txt
#   inflating: /content/1900s/fic_1904_1304.txt
#   inflating: /content/1900s/news_1903_676444.txt
#   inflating: /content/1900s/fic_1906_14214.txt
#   inflating: /content/1900s/news_1904_676609.txt
#   inflating: /content/1900s/fic_1902_2318.txt
#   inflating: /content/1900s/news_1902_676004.txt
#   inflating: /content/1900s/news_1903_676478.txt
#   inflating: /content/1900s/news_1902_676010.txt
#   inflating: /content/1900s/news_1900_675427.txt
#   inflating: /content/1900s/news_1900_675433.txt
#   inflating: /content/1900s/news_1908_677949.txt
#   inflating: /content/1900s/news_1907_677727.txt
#   inflating: /content/1900s/news_1906_677429.txt
#   inflating: /content/1900s/news_1901_675715.txt
#   inflating: /content/1900s/news_1904_676812.txt
#   inflating: /content/1900s/news_1906_677367.txt
#   inflating: /content/1900s/news_1907_781099.txt
#   inflating: /content/1900s/news_1909_781447.txt
#   inflating: /content/1900s/fic_1900_2363.txt
#   inflating: /content/1900s/mag_1904_473951.txt
#   inflating: /content/1900s/fic_1909_2482.txt
#   inflating: /content/1900s/mag_1907_430319.txt
#   inflating: /content/1900s/news_1904_676741.txt
#   inflating: /content/1900s/news_1900_675590.txt
#   inflating: /content/1900s/news_1907_677684.txt
#   inflating: /content/1900s/news_1904_676755.txt
#   inflating: /content/1900s/news_1905_677023.txt
#   inflating: /content/1900s/news_1903_676256.txt
#   inflating: /content/1900s/mag_1907_486901.txt
#   inflating: /content/1900s/mag_1907_430325.txt
#   inflating: /content/1900s/mag_1908_430393.txt
#   inflating: /content/1900s/fic_1901_199.txt
#   inflating: /content/1900s/mag_1901_473363.txt
#   inflating: /content/1900s/mag_1902_430081.txt
#   inflating: /content/1900s/news_1909_678627.txt
#   inflating: /content/1900s/mag_1907_430331.txt
#   inflating: /content/1900s/mag_1908_430387.txt
#   inflating: /content/1900s/news_1904_676782.txt
#   inflating: /content/1900s/fic_1907_13929.txt
#   inflating: /content/1900s/news_1900_675547.txt
#   inflating: /content/1900s/news_1907_677653.txt
#   inflating: /content/1900s/mag_1908_430378.txt
#   inflating: /content/1900s/news_1904_676796.txt
#   inflating: /content/1900s/mag_1905_430233.txt
#   inflating: /content/1900s/mag_1908_430350.txt
#   inflating: /content/1900s/fic_1907_1223.txt
#   inflating: /content/1900s/mag_1902_430056.txt
#   inflating: /content/1900s/mag_1904_430129.txt
#   inflating: /content/1900s/news_1906_677207.txt
#   inflating: /content/1900s/mag_1909_437725.txt
#   inflating: /content/1900s/news_1901_675675.txt
#   inflating: /content/1900s/mag_1905_430227.txt
#   inflating: /content/1900s/news_1907_677486.txt
#   inflating: /content/1900s/fic_1902_13488.txt
#   inflating: /content/1900s/mag_1906_438649.txt
#   inflating: /content/1900s/mag_1906_474331.txt
#   inflating: /content/1900s/news_1907_677492.txt
#   inflating: /content/1900s/news_1909_678357.txt
#   inflating: /content/1900s/news_1908_678059.txt
#   inflating: /content/1900s/mag_1906_474319.txt
#   inflating: /content/1900s/news_1909_678425.txt
#   inflating: /content/1900s/news_1909_678343.txt
#   inflating: /content/1900s/news_1903_781379.txt
#   inflating: /content/1900s/fic_1900_2983.txt
#   inflating: /content/1900s/mag_1904_439327.txt
#   inflating: /content/1900s/news_1904_676580.txt
#   inflating: /content/1900s/news_1904_676594.txt
#   inflating: /content/1900s/mag_1908_474738.txt
#   inflating: /content/1900s/fic_1902_13339.txt
#   inflating: /content/1900s/fic_1909_1410.txt
#   inflating: /content/1900s/news_1907_677479.txt
#   inflating: /content/1900s/news_1909_678394.txt
#   inflating: /content/1900s/news_1903_781423.txt
#   inflating: /content/1900s/news_1908_781359.txt
#   inflating: /content/1900s/nf_1906_752270.txt
#   inflating: /content/1900s/news_1909_678381.txt
#   inflating: /content/1900s/mag_1901_486328.txt
#   inflating: /content/1900s/news_1908_781358.txt
#   inflating: /content/1900s/news_1907_677478.txt
#   inflating: /content/1900s/news_1903_781422.txt
#   inflating: /content/1900s/news_1904_676595.txt
#   inflating: /content/1900s/news_1907_677450.txt
#   inflating: /content/1900s/news_1903_781378.txt
#   inflating: /content/1900s/news_1904_676581.txt
#   inflating: /content/1900s/mag_1904_439326.txt
#   inflating: /content/1900s/news_1909_678424.txt
#   inflating: /content/1900s/mag_1902_486642.txt
#   inflating: /content/1900s/news_1902_781089.txt
#   inflating: /content/1900s/news_1908_678058.txt
#   inflating: /content/1900s/news_1907_780999.txt
#   inflating: /content/1900s/news_1909_678418.txt
#   inflating: /content/1900s/mag_1907_438234.txt
#   inflating: /content/1900s/news_1907_677487.txt
#   inflating: /content/1900s/news_1908_678064.txt
#   inflating: /content/1900s/mag_1904_430128.txt
#   inflating: /content/1900s/mag_1905_430226.txt
#   inflating: /content/1900s/fic_1909_49.txt
#   inflating: /content/1900s/mag_1908_430351.txt
#   inflating: /content/1900s/mag_1905_430232.txt
#   inflating: /content/1900s/news_1908_678299.txt
#   inflating: /content/1900s/mag_1902_430057.txt
#   inflating: /content/1900s/news_1907_677652.txt
#   inflating: /content/1900s/news_1900_675546.txt
#   inflating: /content/1900s/news_1901_675890.txt
#   inflating: /content/1900s/mag_1905_486816.txt
#   inflating: /content/1900s/mag_1908_430379.txt
#   inflating: /content/1900s/news_1904_676783.txt
#   inflating: /content/1900s/mag_1908_438057.txt
#   inflating: /content/1900s/news_1907_677646.txt
#   inflating: /content/1900s/mag_1902_430080.txt
#   inflating: /content/1900s/mag_1908_430386.txt
#   inflating: /content/1900s/mag_1907_430330.txt
#   inflating: /content/1900s/mag_1908_430392.txt
#   inflating: /content/1900s/mag_1907_430324.txt
#   inflating: /content/1900s/news_1907_677861.txt
#   inflating: /content/1900s/news_1903_676531.txt
#   inflating: /content/1900s/fic_1907_644.txt
#   inflating: /content/1900s/news_1908_678272.txt
#   inflating: /content/1900s/mag_1907_486900.txt
#   inflating: /content/1900s/news_1901_675853.txt
#   inflating: /content/1900s/mag_1904_473944.txt
#   inflating: /content/1900s/news_1905_677022.txt
#   inflating: /content/1900s/news_1905_677036.txt
#   inflating: /content/1900s/news_1904_676740.txt
#   inflating: /content/1900s/mag_1907_430318.txt
#   inflating: /content/1900s/mag_1909_437650.txt
#   inflating: /content/1900s/news_1902_780988.txt
#   inflating: /content/1900s/news_1907_781098.txt
#   inflating: /content/1900s/news_1906_677414.txt
#   inflating: /content/1900s/news_1904_676813.txt
#   inflating: /content/1900s/fic_1901_4713.txt
#   inflating: /content/1900s/news_1908_677948.txt
#   inflating: /content/1900s/mag_1907_457546.txt
#   inflating: /content/1900s/news_1906_677428.txt
#   inflating: /content/1900s/news_1901_675728.txt
#   inflating: /content/1900s/news_1902_781300.txt
#   inflating: /content/1900s/news_1900_675426.txt
#   inflating: /content/1900s/news_1903_676492.txt
#   inflating: /content/1900s/mag_1909_474966.txt
#   inflating: /content/1900s/news_1902_676011.txt
#   inflating: /content/1900s/news_1903_676479.txt
#   inflating: /content/1900s/mag_1905_438901.txt
#   inflating: /content/1900s/news_1904_676608.txt
#   inflating: /content/1900s/mag_1907_457585.txt
#   inflating: /content/1900s/news_1903_676445.txt
#   inflating: /content/1900s/fic_1902_13933.txt
#   inflating: /content/1900s/news_1908_678306.txt
#   inflating: /content/1900s/news_1903_676337.txt
#   inflating: /content/1900s/news_1902_676039.txt
#   inflating: /content/1900s/mag_1900_430009.txt
#   inflating: /content/1900s/mag_1905_430150.txt
#   inflating: /content/1900s/news_1906_677170.txt
#   inflating: /content/1900s/news_1907_677518.txt
#   inflating: /content/1900s/news_1909_678587.txt
#   inflating: /content/1900s/mag_1905_486590.txt
#   inflating: /content/1900s/mag_1901_486506.txt
#   inflating: /content/1900s/fic_1900_5141.txt
#   inflating: /content/1900s/news_1902_675929.txt
#   inflating: /content/1900s/news_1905_676923.txt
#   inflating: /content/1900s/mag_1905_430178.txt
#   inflating: /content/1900s/mag_1905_430193.txt
#   inflating: /content/1900s/news_1902_676213.txt
#   inflating: /content/1900s/fic_1907_4951.txt
#   inflating: /content/1900s/news_1902_676207.txt
#   inflating: /content/1900s/mag_1905_430187.txt
#   inflating: /content/1900s/news_1908_678104.txt
#   inflating: /content/1900s/mag_1904_439285.txt
#   inflating: /content/1900s/fic_1902_463.txt
#   inflating: /content/1900s/mag_1909_486716.txt
#   inflating: /content/1900s/mag_1901_440390.txt
#   inflating: /content/1900s/mag_1903_473843.txt
#   inflating: /content/1900s/mag_1905_430183.txt
#   inflating: /content/1900s/news_1909_678554.txt
#   inflating: /content/1900s/mag_1907_474600.txt
#   inflating: /content/1900s/mag_1905_430197.txt
#   inflating: /content/1900s/fic_1902_3215.txt
#   inflating: /content/1900s/mag_1906_438738.txt
#   inflating: /content/1900s/news_1907_677508.txt
#   inflating: /content/1900s/news_1906_677174.txt
#   inflating: /content/1900s/news_1909_678597.txt
#   inflating: /content/1900s/mag_1905_430154.txt
#   inflating: /content/1900s/news_1905_676927.txt
#   inflating: /content/1900s/news_1907_677520.txt
#   inflating: /content/1900s/news_1905_676933.txt
#   inflating: /content/1900s/mag_1905_430168.txt
#   inflating: /content/1900s/news_1904_676624.txt
#   inflating: /content/1900s/mag_1900_440515.txt
#   inflating: /content/1900s/news_1906_677404.txt
#   inflating: /content/1900s/news_1904_676817.txt
#   inflating: /content/1900s/news_1901_675710.txt
#   inflating: /content/1900s/news_1909_781442.txt
#   inflating: /content/1900s/fic_1902_842.txt
#   inflating: /content/1900s/news_1908_677958.txt
#   inflating: /content/1900s/news_1907_677736.txt
#   inflating: /content/1900s/news_1903_676496.txt
#   inflating: /content/1900s/news_1900_675422.txt
#   inflating: /content/1900s/news_1906_677438.txt
#   inflating: /content/1900s/fic_1901_2428.txt
#   inflating: /content/1900s/news_1901_675738.txt
#   inflating: /content/1900s/fic_1909_4633.txt
#   inflating: /content/1900s/mag_1907_438185.txt
#   inflating: /content/1900s/news_1907_677722.txt
#   inflating: /content/1900s/news_1902_676175.txt
#   inflating: /content/1900s/mag_1907_430320.txt
#   inflating: /content/1900s/mag_1908_430396.txt
#   inflating: /content/1900s/mag_1907_430334.txt
#   inflating: /content/1900s/mag_1908_430382.txt
#   inflating: /content/1900s/news_1907_677871.txt
#   inflating: /content/1900s/mag_1902_430084.txt
#   inflating: /content/1900s/news_1902_676149.txt
#   inflating: /content/1900s/mag_1908_438090.txt
#   inflating: /content/1900s/mag_1907_486910.txt
#   inflating: /content/1900s/fic_1907_2908.txt
#   inflating: /content/1900s/news_1908_678262.txt
#   inflating: /content/1900s/news_1904_676744.txt
#   inflating: /content/1900s/news_1905_677032.txt
#   inflating: /content/1900s/mag_1907_430308.txt
#   inflating: /content/1900s/mag_1907_486904.txt
#   inflating: /content/1900s/news_1908_678276.txt
#   inflating: /content/1900s/news_1907_677695.txt
#   inflating: /content/1900s/news_1903_676535.txt
#   inflating: /content/1900s/mag_1909_437734.txt
#   inflating: /content/1900s/mag_1902_430053.txt
#   inflating: /content/1900s/mag_1904_430138.txt
#   inflating: /content/1900s/mag_1905_430236.txt
#   inflating: /content/1900s/mag_1908_430355.txt
#   inflating: /content/1900s/news_1902_781258.txt
#   inflating: /content/1900s/news_1908_678289.txt
#   inflating: /content/1900s/mag_1905_430222.txt
#   inflating: /content/1900s/news_1906_677202.txt
#   inflating: /content/1900s/mag_1908_430369.txt
#   inflating: /content/1900s/mag_1905_486806.txt
#   inflating: /content/1900s/news_1904_676787.txt
#   inflating: /content/1900s/mag_1901_473399.txt
#   inflating: /content/1900s/news_1903_676290.txt
#   inflating: /content/1900s/news_1909_678434.txt
#   inflating: /content/1900s/nf_1901_774001.txt
#   inflating: /content/1900s/mag_1902_486646.txt
#   inflating: /content/1900s/news_1901_781256.txt
#   inflating: /content/1900s/news_1909_678346.txt
#   inflating: /content/1900s/news_1909_678408.txt
#   inflating: /content/1900s/news_1907_677497.txt
#   inflating: /content/1900s/news_1907_677468.txt
#   inflating: /content/1900s/mag_1903_473728.txt
#   inflating: /content/1900s/mag_1905_439038.txt
#   inflating: /content/1900s/mag_1902_473432.txt
#   inflating: /content/1900s/mag_1905_474139.txt
#   inflating: /content/1900s/news_1907_677455.txt
#   inflating: /content/1900s/news_1909_678409.txt
#   inflating: /content/1900s/news_1908_678061.txt
#   inflating: /content/1900s/mag_1907_438225.txt
#   inflating: /content/1900s/mag_1906_438665.txt
#   inflating: /content/1900s/mag_1902_486653.txt
#   inflating: /content/1900s/news_1909_678347.txt
#   inflating: /content/1900s/news_1909_678421.txt
#   inflating: /content/1900s/news_1908_678049.txt
#   inflating: /content/1900s/news_1909_678435.txt
#   inflating: /content/1900s/news_1901_781257.txt
#   inflating: /content/1900s/news_1904_676792.txt
#   inflating: /content/1900s/mag_1900_473082.txt
#   inflating: /content/1900s/mag_1908_430368.txt
#   inflating: /content/1900s/mag_1905_430223.txt
#   inflating: /content/1900s/news_1908_678288.txt
#   inflating: /content/1900s/news_1902_781259.txt
#   inflating: /content/1900s/news_1906_677203.txt
#   inflating: /content/1900s/mag_1904_430139.txt
#   inflating: /content/1900s/mag_1902_430052.txt
#   inflating: /content/1900s/mag_1908_430354.txt
#   inflating: /content/1900s/fic_1900_3119.txt
#   inflating: /content/1900s/mag_1905_430237.txt
#   inflating: /content/1900s/news_1908_678277.txt
#   inflating: /content/1900s/news_1905_677027.txt
#   inflating: /content/1900s/mag_1907_430309.txt
#   inflating: /content/1900s/news_1900_675580.txt
#   inflating: /content/1900s/news_1903_676534.txt
#   inflating: /content/1900s/fic_1902_5249.txt
#   inflating: /content/1900s/news_1900_781415.txt
#   inflating: /content/1900s/news_1907_677680.txt
#   inflating: /content/1900s/news_1900_675594.txt
#   inflating: /content/1900s/news_1903_676520.txt
#   inflating: /content/1900s/news_1902_676148.txt
#   inflating: /content/1900s/news_1904_676745.txt
#   inflating: /content/1900s/news_1901_675842.txt
#   inflating: /content/1900s/mag_1907_486911.txt
#   inflating: /content/1900s/mag_1908_430383.txt
#   inflating: /content/1900s/mag_1907_430335.txt
#   inflating: /content/1900s/mag_1901_473373.txt
#   inflating: /content/1900s/mag_1902_430085.txt
#   inflating: /content/1900s/news_1907_677870.txt
#   inflating: /content/1900s/news_1902_676160.txt
#   inflating: /content/1900s/news_1902_676174.txt
#   inflating: /content/1900s/news_1907_677864.txt
#   inflating: /content/1900s/news_1909_678637.txt
#   inflating: /content/1900s/mag_1908_430397.txt
#   inflating: /content/1900s/mag_1907_430321.txt
#   inflating: /content/1900s/news_1904_676779.txt
#   inflating: /content/1900s/news_1901_675739.txt
#   inflating: /content/1900s/news_1907_677723.txt
#   inflating: /content/1900s/nf_1900_773924.txt
#   inflating: /content/1900s/fic_1904_2812.txt
#   inflating: /content/1900s/news_1900_675423.txt
#   inflating: /content/1900s/news_1903_676497.txt
#   inflating: /content/1900s/news_1907_677737.txt
#   inflating: /content/1900s/mag_1909_474988.txt
#   inflating: /content/1900s/news_1906_677439.txt
#   inflating: /content/1900s/fic_1900_4716.txt
#   inflating: /content/1900s/nf_1900_754419.txt
#   inflating: /content/1900s/news_1904_676802.txt
#   inflating: /content/1900s/news_1906_677377.txt
#   inflating: /content/1900s/news_1908_677965.txt
#   inflating: /content/1900s/news_1903_676326.txt
#   inflating: /content/1900s/news_1902_676028.txt
#   inflating: /content/1900s/news_1909_678743.txt
#   inflating: /content/1900s/news_1905_676932.txt
#   inflating: /content/1900s/news_1907_677521.txt
#   inflating: /content/1900s/mag_1905_430169.txt
#   inflating: /content/1900s/mag_1906_474282.txt
#   inflating: /content/1900s/news_1905_676926.txt
#   inflating: /content/1900s/news_1906_677175.txt
#   inflating: /content/1900s/mag_1905_430155.txt
#   inflating: /content/1900s/news_1908_678101.txt
#   inflating: /content/1900s/news_1909_678569.txt
#   inflating: /content/1900s/news_1908_678115.txt
#   inflating: /content/1900s/mag_1909_486707.txt
#   inflating: /content/1900s/news_1902_676216.txt
#   inflating: /content/1900s/mag_1905_430196.txt
#   inflating: /content/1900s/nf_1907_773770.txt
#   inflating: /content/1900s/news_1904_781093.txt
#   inflating: /content/1900s/news_1908_678129.txt
#   inflating: /content/1900s/mag_1905_430182.txt
#   inflating: /content/1900s/news_1909_678541.txt
#   inflating: /content/1900s/mag_1905_430194.txt
#   inflating: /content/1900s/news_1902_676200.txt
#   inflating: /content/1900s/news_1909_678543.txt
#   inflating: /content/1900s/mag_1905_430180.txt
#   inflating: /content/1900s/mag_1908_474689.txt
#   inflating: /content/1900s/news_1908_678103.txt
#   inflating: /content/1900s/news_1902_676228.txt
#   inflating: /content/1900s/mag_1909_486711.txt
#   inflating: /content/1900s/news_1906_677188.txt
#   inflating: /content/1900s/mag_1905_430157.txt
#   inflating: /content/1900s/mag_1908_437983.txt
#   inflating: /content/1900s/mag_1905_474073.txt
#   inflating: /content/1900s/news_1906_677177.txt
#   inflating: /content/1900s/news_1905_676918.txt
#   inflating: /content/1900s/news_1907_677523.txt
#   inflating: /content/1900s/news_1905_676924.txt
#   inflating: /content/1900s/fic_1908_2725.txt
#   inflating: /content/1900s/mag_1906_474280.txt
#   inflating: /content/1900s/mag_1909_437694.txt
#   inflating: /content/1900s/news_1902_676016.txt
#   inflating: /content/1900s/news_1904_676627.txt
#   inflating: /content/1900s/news_1903_676324.txt
#   inflating: /content/1900s/news_1908_678301.txt
#   inflating: /content/1900s/news_1904_676633.txt
#   inflating: /content/1900s/news_1905_677145.txt
#   inflating: /content/1900s/news_1909_781441.txt
#   inflating: /content/1900s/news_1906_677375.txt
#   inflating: /content/1900s/news_1908_677973.txt
#   inflating: /content/1900s/news_1900_675409.txt
#   inflating: /content/1900s/nf_1904_766417.txt
#   inflating: /content/1900s/news_1901_675707.txt
#   inflating: /content/1900s/news_1906_677413.txt
#   inflating: /content/1900s/news_1906_677407.txt
#   inflating: /content/1900s/news_1901_675713.txt
#   inflating: /content/1900s/news_1904_676814.txt
#   inflating: /content/1900s/news_1906_677349.txt
#   inflating: /content/1900s/news_1902_676162.txt
#   inflating: /content/1900s/news_1901_781043.txt
#   inflating: /content/1900s/news_1908_678249.txt
#   inflating: /content/1900s/mag_1907_430337.txt
#   inflating: /content/1900s/news_1901_675868.txt
#   inflating: /content/1900s/mag_1908_430381.txt
#   inflating: /content/1900s/mag_1907_430323.txt
#   inflating: /content/1900s/mag_1908_430395.txt
#   inflating: /content/1900s/news_1907_677866.txt
#   inflating: /content/1900s/news_1902_676176.txt
#   inflating: /content/1900s/news_1907_677696.txt
#   inflating: /content/1900s/news_1903_676536.txt
#   inflating: /content/1900s/news_1905_677025.txt
#   inflating: /content/1900s/news_1908_678275.txt
#   inflating: /content/1900s/news_1909_678609.txt
#   inflating: /content/1900s/mag_1901_473359.txt
#   inflating: /content/1900s/news_1904_676747.txt
#   inflating: /content/1900s/news_1907_677669.txt
#   inflating: /content/1900s/news_1906_677201.txt
#   inflating: /content/1900s/mag_1905_430221.txt
#   inflating: /content/1900s/mag_1905_430235.txt
#   inflating: /content/1900s/mag_1908_430356.txt
#   inflating: /content/1900s/news_1901_675667.txt
#   inflating: /content/1900s/mag_1904_486289.txt
#   inflating: /content/1900s/mag_1905_486839.txt
#   inflating: /content/1900s/mag_1900_485058.txt
#   inflating: /content/1900s/mag_1902_430050.txt
#   inflating: /content/1900s/news_1906_677215.txt
#   inflating: /content/1900s/news_1900_675541.txt
#   inflating: /content/1900s/mag_1902_430078.txt
#   inflating: /content/1900s/news_1904_676790.txt
#   inflating: /content/1900s/mag_1905_486811.txt
#   inflating: /content/1900s/mag_1905_430209.txt
#   inflating: /content/1900s/news_1906_677229.txt
#   inflating: /content/1900s/news_1900_675555.txt
#   inflating: /content/1900s/news_1902_676189.txt
#   inflating: /content/1900s/news_1909_678423.txt
#   inflating: /content/1900s/mag_1902_486651.txt
#   inflating: /content/1900s/mag_1902_486645.txt
#   inflating: /content/1900s/news_1909_678351.txt
#   inflating: /content/1900s/news_1901_781255.txt
#   inflating: /content/1900s/news_1908_678077.txt
#   inflating: /content/1900s/fic_1909_13930.txt
#   inflating: /content/1900s/news_1907_677480.txt
#   inflating: /content/1900s/news_1908_678063.txt
#   inflating: /content/1900s/news_1908_678088.txt
#   inflating: /content/1900s/news_1909_678392.txt
#   inflating: /content/1900s/mag_1905_474113.txt
#   inflating: /content/1900s/mag_1906_438698.txt
#   inflating: /content/1900s/news_1904_676586.txt
#   inflating: /content/1900s/news_1908_678089.txt
#   inflating: /content/1900s/news_1908_678076.txt
#   inflating: /content/1900s/mag_1902_440039.txt
#   inflating: /content/1900s/news_1907_677495.txt
#   inflating: /content/1900s/fic_1909_2863.txt
#   inflating: /content/1900s/news_1909_678436.txt
#   inflating: /content/1900s/mag_1902_486650.txt
#   inflating: /content/1900s/news_1909_678344.txt
#   inflating: /content/1900s/mag_1905_430208.txt
#   inflating: /content/1900s/news_1904_676785.txt
#   inflating: /content/1900s/news_1903_676286.txt
#   inflating: /content/1900s/mag_1908_438051.txt
#   inflating: /content/1900s/news_1902_676188.txt
#   inflating: /content/1900s/news_1900_675554.txt
#   inflating: /content/1900s/fic_1900_3898.txt
#   inflating: /content/1900s/mag_1902_430079.txt
#   inflating: /content/1900s/news_1907_677654.txt
#   inflating: /content/1900s/news_1900_675540.txt
#   inflating: /content/1900s/mag_1905_486810.txt
#   inflating: /content/1900s/news_1904_676791.txt
#   inflating: /content/1900s/mag_1905_486838.txt
#   inflating: /content/1900s/news_1901_675666.txt
#   inflating: /content/1900s/mag_1908_430357.txt
#   inflating: /content/1900s/mag_1905_430234.txt
#   inflating: /content/1900s/news_1906_677214.txt
#   inflating: /content/1900s/mag_1902_430051.txt
#   inflating: /content/1900s/news_1900_675568.txt
#   inflating: /content/1900s/mag_1900_485059.txt
#   inflating: /content/1900s/mag_1908_438079.txt
#   inflating: /content/1900s/mag_1905_430220.txt
#   inflating: /content/1900s/fic_1900_2210.txt
#   inflating: /content/1900s/nf_1904_771778.txt
#   inflating: /content/1900s/news_1901_675699.txt
#   inflating: /content/1900s/news_1909_678608.txt
#   inflating: /content/1900s/news_1907_677683.txt
#   inflating: /content/1900s/mag_1908_438092.txt
#   inflating: /content/1900s/news_1903_676537.txt
#   inflating: /content/1900s/news_1900_675583.txt
#   inflating: /content/1900s/news_1900_781416.txt
#   inflating: /content/1900s/news_1908_678274.txt
#   inflating: /content/1900s/news_1905_677024.txt
#   inflating: /content/1900s/mag_1908_430394.txt
#   inflating: /content/1900s/mag_1907_430322.txt
#   inflating: /content/1900s/mag_1902_430086.txt
#   inflating: /content/1900s/mag_1908_430380.txt
#   inflating: /content/1900s/news_1902_781299.txt
#   inflating: /content/1900s/mag_1907_430336.txt
#   inflating: /content/1900s/news_1908_678248.txt
#   inflating: /content/1900s/mag_1907_474574.txt
#   inflating: /content/1900s/news_1904_676829.txt
#   inflating: /content/1900s/news_1907_677720.txt
#   inflating: /content/1900s/news_1906_677348.txt
#   inflating: /content/1900s/mag_1907_438187.txt
#   inflating: /content/1900s/news_1906_677406.txt
#   inflating: /content/1900s/mag_1907_486899.txt
#   inflating: /content/1900s/news_1907_677708.txt
#   inflating: /content/1900s/news_1908_677972.txt
#   inflating: /content/1900s/fic_1902_840.txt
#   inflating: /content/1900s/news_1909_781440.txt
#   inflating: /content/1900s/nf_1909_750979.txt
#   inflating: /content/1900s/news_1904_676801.txt
#   inflating: /content/1900s/news_1903_676331.txt
#   inflating: /content/1900s/news_1904_676632.txt
#   inflating: /content/1900s/news_1905_677144.txt
#   inflating: /content/1900s/mag_1903_439596.txt
#   inflating: /content/1900s/news_1908_678314.txt
#   inflating: /content/1900s/news_1908_677999.txt
#   inflating: /content/1900s/news_1903_676443.txt
#   inflating: /content/1900s/news_1908_678300.txt
#   inflating: /content/1900s/news_1903_676325.txt
#   inflating: /content/1900s/news_1905_677150.txt
#   inflating: /content/1900s/news_1909_678740.txt
#   inflating: /content/1900s/news_1901_675909.txt
#   inflating: /content/1900s/news_1902_676017.txt
#   inflating: /content/1900s/news_1903_676319.txt
#   inflating: /content/1900s/news_1907_677536.txt
#   inflating: /content/1900s/news_1905_676925.txt
#   inflating: /content/1900s/mag_1901_440341.txt
#   inflating: /content/1900s/nf_1906_773482.txt
#   inflating: /content/1900s/mag_1904_439240.txt
#   inflating: /content/1900s/mag_1902_473544.txt
#   inflating: /content/1900s/mag_1901_440433.txt
#   inflating: /content/1900s/news_1905_676919.txt
#   inflating: /content/1900s/mag_1905_430156.txt
#   inflating: /content/1900s/news_1909_678595.txt
#   inflating: /content/1900s/fic_1906_1152.txt
#   inflating: /content/1900s/mag_1903_473676.txt
#   inflating: /content/1900s/mag_1909_486704.txt
#   inflating: /content/1900s/fic_1902_3559.txt
#   inflating: /content/1900s/news_1908_678116.txt
#   inflating: /content/1900s/news_1906_677189.txt
#   inflating: /content/1900s/news_1902_676201.txt
#   inflating: /content/1900s/mag_1905_430181.txt
#   inflating: /content/1900s/mag_1905_430195.txt
#   inflating: /content/1900s/fic_1902_1366.txt
#   inflating: /content/1900s/news_1908_678165.txt
#   inflating: /content/1900s/news_1907_677586.txt
#   inflating: /content/1900s/nf_1900_773559.txt
#   inflating: /content/1900s/news_1905_676995.txt
#   inflating: /content/1900s/mag_1906_430301.txt
#   inflating: /content/1900s/news_1905_676981.txt
#   inflating: /content/1900s/news_1907_677592.txt
#   inflating: /content/1900s/news_1909_678519.txt
#   inflating: /content/1900s/news_1908_678171.txt
#   inflating: /content/1900s/news_1909_678531.txt
#   inflating: /content/1900s/mag_1903_430099.txt
#   inflating: /content/1900s/mag_1901_485091.txt
#   inflating: /content/1900s/news_1901_781353.txt
#   inflating: /content/1900s/fic_1903_5601.txt
#   inflating: /content/1900s/news_1907_677545.txt
#   inflating: /content/1900s/news_1907_677551.txt
#   inflating: /content/1900s/news_1902_675948.txt
#   inflating: /content/1900s/news_1905_676942.txt
#   inflating: /content/1900s/news_1905_781306.txt
#   inflating: /content/1900s/fic_1909_4440.txt
#   inflating: /content/1900s/mag_1909_430412.txt
#   inflating: /content/1900s/mag_1903_439730.txt
#   inflating: /content/1900s/news_1907_677579.txt
#   inflating: /content/1900s/mag_1900_440772.txt
#   inflating: /content/1900s/news_1902_675974.txt
#   inflating: /content/1900s/mag_1909_486575.txt
#   inflating: /content/1900s/mag_1905_438948.txt
#   inflating: /content/1900s/fic_1908_4681.txt
#   inflating: /content/1900s/mag_1903_486673.txt
#   inflating: /content/1900s/news_1903_676356.txt
#   inflating: /content/1900s/news_1907_677790.txt
#   inflating: /content/1900s/news_1900_675484.txt
#   inflating: /content/1900s/fic_1906_14506.txt
#   inflating: /content/1900s/news_1909_678733.txt
#   inflating: /content/1900s/mag_1905_438960.txt
#   inflating: /content/1900s/mag_1901_473277.txt
#   inflating: /content/1900s/news_1909_678727.txt
#   inflating: /content/1900s/news_1904_676669.txt
#   inflating: /content/1900s/news_1907_677747.txt
#   inflating: /content/1900s/fic_1905_13936.txt
#   inflating: /content/1900s/news_1900_675453.txt
#   inflating: /content/1900s/news_1901_675749.txt
#   inflating: /content/1900s/mag_1900_440564.txt
#   inflating: /content/1900s/news_1904_676866.txt
#   inflating: /content/1900s/news_1901_675775.txt
#   inflating: /content/1900s/mag_1908_486690.txt
#   inflating: /content/1900s/news_1906_677307.txt
#   inflating: /content/1900s/news_1908_677901.txt
#   inflating: /content/1900s/news_1905_781138.txt
#   inflating: /content/1900s/mag_1905_474203.txt
#   inflating: /content/1900s/mag_1907_457490.txt
#   inflating: /content/1900s/news_1906_677298.txt
#   inflating: /content/1900s/news_1905_677057.txt
#   inflating: /content/1900s/news_1904_676721.txt
#   inflating: /content/1900s/nf_1904_773685.txt
#   inflating: /content/1900s/nf_1906_773988.txt
#   inflating: /content/1900s/news_1902_676104.txt
#   inflating: /content/1900s/news_1904_676709.txt
#   inflating: /content/1900s/mag_1904_473919.txt
#   inflating: /content/1900s/news_1909_678647.txt
#   inflating: /content/1900s/news_1909_678653.txt
#   inflating: /content/1900s/mag_1901_473303.txt
#   inflating: /content/1900s/mag_1907_430345.txt
#   inflating: /content/1900s/news_1904_781381.txt
#   inflating: /content/1900s/news_1903_676578.txt
#   inflating: /content/1900s/news_1900_675527.txt
#   inflating: /content/1900s/mag_1900_485016.txt
#   inflating: /content/1900s/mag_1909_437779.txt
#   inflating: /content/1900s/fic_1909_4044.txt
#   inflating: /content/1900s/news_1900_675533.txt
#   inflating: /content/1900s/mag_1908_486928.txt
#   inflating: /content/1900s/news_1904_781424.txt
#   inflating: /content/1900s/news_1908_678011.txt
#   inflating: /content/1900s/news_1909_678479.txt
#   inflating: /content/1900s/mag_1907_438255.txt
#   inflating: /content/1900s/mag_1906_430261.txt
#   inflating: /content/1900s/mag_1906_430275.txt
#   inflating: /content/1900s/mag_1909_486617.txt
#   inflating: /content/1900s/mag_1906_486879.txt
#   inflating: /content/1900s/mag_1904_439384.txt
#   inflating: /content/1900s/mag_1901_430038.txt
#   inflating: /content/1900s/mag_1902_486637.txt
#   inflating: /content/1900s/mag_1906_486851.txt
#   inflating: /content/1900s/news_1909_678337.txt
#   inflating: /content/1900s/fic_1902_3476.txt
#   inflating: /content/1900s/mag_1904_486748.txt
#   inflating: /content/1900s/mag_1902_486623.txt
#   inflating: /content/1900s/mag_1906_430249.txt
#   inflating: /content/1900s/news_1908_678039.txt
#   inflating: /content/1900s/news_1909_678451.txt
#   inflating: /content/1900s/mag_1904_439353.txt
#   inflating: /content/1900s/mag_1903_430112.txt
#   inflating: /content/1900s/mag_1903_430106.txt
#   inflating: /content/1900s/news_1903_780991.txt
#   inflating: /content/1900s/news_1909_678486.txt
#   inflating: /content/1900s/fic_1903_75.txt
#   inflating: /content/1900s/fic_1909_5602.txt
#   inflating: /content/1900s/mag_1906_486886.txt
#   inflating: /content/1900s/fic_1907_5227.txt
#   inflating: /content/1900s/mag_1905_474174.txt
#   inflating: /content/1900s/news_1903_780990.txt
#   inflating: /content/1900s/mag_1905_439048.txt
#   inflating: /content/1900s/mag_1903_430107.txt
#   inflating: /content/1900s/mag_1902_473442.txt
#   inflating: /content/1900s/mag_1907_485064.txt
#   inflating: /content/1900s/mag_1903_430113.txt
#   inflating: /content/1900s/mag_1904_439352.txt
#   inflating: /content/1900s/mag_1903_473758.txt
#   inflating: /content/1900s/mag_1906_430248.txt
#   inflating: /content/1900s/mag_1902_486622.txt
#   inflating: /content/1900s/mag_1906_438614.txt
#   inflating: /content/1900s/fic_1901_13185.txt
#   inflating: /content/1900s/news_1909_678450.txt
#   inflating: /content/1900s/mag_1901_430039.txt
#   inflating: /content/1900s/news_1909_678444.txt
#   inflating: /content/1900s/mag_1902_486636.txt
#   inflating: /content/1900s/mag_1907_438268.txt
#   inflating: /content/1900s/mag_1906_486878.txt
#   inflating: /content/1900s/mag_1906_474436.txt
#   inflating: /content/1900s/mag_1906_430274.txt
#   inflating: /content/1900s/mag_1901_440290.txt
#   inflating: /content/1900s/nf_1907_773885.txt
#   inflating: /content/1900s/news_1909_678478.txt
#   inflating: /content/1900s/mag_1906_430260.txt
#   inflating: /content/1900s/news_1909_678685.txt
#   inflating: /content/1900s/mag_1908_486929.txt
#   inflating: /content/1900s/news_1905_677095.txt
#   inflating: /content/1900s/news_1900_675532.txt
#   inflating: /content/1900s/fic_1908_500.txt
#   inflating: /content/1900s/news_1907_677632.txt
#   inflating: /content/1900s/news_1904_781380.txt
#   inflating: /content/1900s/mag_1907_430344.txt
#   inflating: /content/1900s/news_1907_677815.txt
#   inflating: /content/1900s/news_1908_678206.txt
#   inflating: /content/1900s/news_1901_675827.txt
#   inflating: /content/1900s/mag_1903_486712.txt
#   inflating: /content/1900s/news_1904_676720.txt
#   inflating: /content/1900s/news_1905_677042.txt
#   inflating: /content/1900s/news_1901_675833.txt
#   inflating: /content/1900s/news_1901_675774.txt
#   inflating: /content/1900s/news_1905_781139.txt
#   inflating: /content/1900s/news_1906_677306.txt
#   inflating: /content/1900s/news_1908_677914.txt
#   inflating: /content/1900s/news_1906_677312.txt
#   inflating: /content/1900s/mag_1905_474216.txt
#   inflating: /content/1900s/news_1901_675760.txt
#   inflating: /content/1900s/news_1901_675748.txt
#   inflating: /content/1900s/mag_1904_473887.txt
#   inflating: /content/1900s/news_1904_676697.txt
#   inflating: /content/1900s/mag_1903_439533.txt
#   inflating: /content/1900s/news_1907_677752.txt
#   inflating: /content/1900s/news_1900_675446.txt
#   inflating: /content/1900s/fic_1907_13182.txt
#   inflating: /content/1900s/news_1900_675452.txt
#   inflating: /content/1900s/mag_1900_473193.txt
#   inflating: /content/1900s/news_1904_676683.txt
#   inflating: /content/1900s/news_1903_676380.txt
#   inflating: /content/1900s/news_1904_676668.txt
#   inflating: /content/1900s/news_1909_678726.txt
#   inflating: /content/1900s/mag_1905_438961.txt
#   inflating: /content/1900s/news_1903_781091.txt
#   inflating: /content/1900s/news_1902_676071.txt
#   inflating: /content/1900s/fic_1907_5839.txt
#   inflating: /content/1900s/news_1909_678732.txt
#   inflating: /content/1900s/mag_1905_438975.txt
#   inflating: /content/1900s/news_1904_676654.txt
#   inflating: /content/1900s/news_1905_677122.txt
#   inflating: /content/1900s/news_1903_676357.txt
#   inflating: /content/1900s/news_1902_676059.txt
#   inflating: /content/1900s/news_1900_675485.txt
#   inflating: /content/1900s/news_1907_677791.txt
#   inflating: /content/1900s/news_1907_677785.txt
#   inflating: /content/1900s/news_1900_675491.txt
#   inflating: /content/1900s/mag_1904_486417.txt
#   inflating: /content/1900s/mag_1903_486672.txt
#   inflating: /content/1900s/mag_1901_440469.txt
#   inflating: /content/1900s/mag_1909_430413.txt
#   inflating: /content/1900s/mag_1902_473522.txt
#   inflating: /content/1900s/nf_1908_760907.txt
#   inflating: /content/1900s/mag_1903_430098.txt
#   inflating: /content/1900s/news_1907_677593.txt
#   inflating: /content/1900s/news_1905_676980.txt
#   inflating: /content/1900s/nf_1902_768907.txt
#   inflating: /content/1900s/mag_1906_430300.txt
#   inflating: /content/1900s/news_1908_678170.txt
#   inflating: /content/1900s/news_1909_678518.txt
#   inflating: /content/1900s/news_1908_678164.txt
#   inflating: /content/1900s/news_1905_676994.txt
#   inflating: /content/1900s/fic_1903_2147.txt
#   inflating: /content/1900s/mag_1908_474820.txt
#   inflating: /content/1900s/mag_1906_430302.txt
#   inflating: /content/1900s/news_1905_676982.txt
#   inflating: /content/1900s/news_1907_677591.txt
#   inflating: /content/1900s/news_1907_677585.txt
#   inflating: /content/1900s/mag_1901_485086.txt
#   inflating: /content/1900s/fic_1904_12527.txt
#   inflating: /content/1900s/news_1909_678532.txt
#   inflating: /content/1900s/mag_1901_485092.txt
#   inflating: /content/1900s/mag_1909_430411.txt
#   inflating: /content/1900s/mag_1901_440443.txt
#   inflating: /content/1900s/news_1907_677552.txt
#   inflating: /content/1900s/news_1905_781305.txt
#   inflating: /content/1900s/news_1905_676955.txt
#   inflating: /content/1900s/mag_1901_440457.txt
#   inflating: /content/1900s/news_1902_675977.txt
#   inflating: /content/1900s/news_1905_676969.txt
#   inflating: /content/1900s/news_1907_677793.txt
#   inflating: /content/1900s/news_1900_675487.txt
#   inflating: /content/1900s/news_1901_675789.txt
#   inflating: /content/1900s/news_1903_676355.txt
#   inflating: /content/1900s/news_1909_678718.txt
#   inflating: /content/1900s/mag_1907_474458.txt
#   inflating: /content/1900s/news_1904_676642.txt
#   inflating: /content/1900s/mag_1909_486576.txt
#   inflating: /content/1900s/news_1902_676067.txt
#   inflating: /content/1900s/mag_1907_474470.txt
#   inflating: /content/1900s/mag_1908_438141.txt
#   inflating: /content/1900s/news_1904_676695.txt
#   inflating: /content/1900s/mag_1904_473891.txt
#   inflating: /content/1900s/news_1904_676681.txt
#   inflating: /content/1900s/news_1904_676859.txt
# ...
#   inflating: /content/1900s/news_1909_678415.txt
#   inflating: /content/1900s/news_1909_678373.txt
#   inflating: /content/1900s/fic_1907_339.txt
#   inflating: /content/1900s/news_1909_678429.txt
#   inflating: /content/1900s/news_1902_781090.txt
#   inflating: /content/1900s/fic_1905_3133.txt
#   inflating: /content/1900s/mag_1901_430040.txt
#   inflating: /content/1900s/nf_1901_774008.txt
#   inflating: /content/1900s/mag_1906_474301.txt
#   inflating: /content/1900s/news_1904_676598.txt
#   inflating: /content/1900s/news_1908_781369.txt
#   inflating: /content/1900s/fic_1905_994.txt
#   inflating: /content/1900s/fic_1901_3475.txt
#   inflating: /content/1900s/news_1908_781433.txt
#   inflating: /content/1900s/news_1908_678082.txt
#   inflating: /content/1900s/news_1907_677461.txt
#   inflating: /content/1900s/news_1908_678096.txt
#   inflating: /content/1900s/news_1908_678083.txt
#   inflating: /content/1900s/news_1907_677460.txt
#   inflating: /content/1900s/news_1904_676599.txt
#   inflating: /content/1900s/news_1908_781368.txt
#   inflating: /content/1900s/mag_1907_438210.txt
#   inflating: /content/1900s/news_1908_678054.txt
#   inflating: /content/1900s/mag_1901_430041.txt
#   inflating: /content/1900s/news_1909_678428.txt
#   inflating: /content/1900s/mag_1906_474314.txt
#   inflating: /content/1900s/news_1908_678040.txt
#   inflating: /content/1900s/fic_1906_103.txt
#   inflating: /content/1900s/news_1909_678366.txt
#   inflating: /content/1900s/fic_1902_5730.txt
#   inflating: /content/1900s/news_1908_678068.txt
#   inflating: /content/1900s/mag_1902_486666.txt
#   inflating: /content/1900s/news_1908_678295.txt
#   inflating: /content/1900s/mag_1905_486832.txt
#   inflating: /content/1900s/news_1900_675562.txt
#   inflating: /content/1900s/fic_1906_12091.txt
#   inflating: /content/1900s/mag_1904_430130.txt
#   inflating: /content/1900s/mag_1904_430124.txt
#   inflating: /content/1900s/nf_1902_773768.txt
#   inflating: /content/1900s/fic_1900_13015.txt
#   inflating: /content/1900s/news_1907_677662.txt
#   inflating: /content/1900s/mag_1905_486826.txt
#   inflating: /content/1900s/mag_1908_430349.txt
#   inflating: /content/1900s/news_1908_678281.txt
#   inflating: /content/1900s/news_1901_675888.txt
#   inflating: /content/1900s/mag_1908_430361.txt
#   inflating: /content/1900s/mag_1905_430202.txt
#   inflating: /content/1900s/mag_1902_430067.txt
#   inflating: /content/1900s/news_1902_676182.txt
#   inflating: /content/1900s/mag_1908_430407.txt
#   inflating: /content/1900s/mag_1909_437700.txt
#   inflating: /content/1900s/news_1906_677236.txt
#   inflating: /content/1900s/news_1907_677886.txt
#   inflating: /content/1900s/mag_1902_430073.txt
#   inflating: /content/1900s/mag_1905_430216.txt
#   inflating: /content/1900s/mag_1908_430375.txt
#   inflating: /content/1900s/mag_1907_430328.txt
#   inflating: /content/1900s/news_1903_676273.txt
#   inflating: /content/1900s/news_1900_781352.txt
#   inflating: /content/1900s/nf_1909_762862.txt
#   inflating: /content/1900s/news_1902_676169.txt
#   inflating: /content/1900s/news_1905_677012.txt
#   inflating: /content/1900s/mag_1901_473352.txt
#   inflating: /content/1900s/news_1909_678602.txt
#   inflating: /content/1900s/mag_1907_430314.txt
#   inflating: /content/1900s/nf_1900_772548.txt
#   inflating: /content/1900s/news_1907_677689.txt
#   inflating: /content/1900s/news_1907_677851.txt
#   inflating: /content/1900s/fic_1909_4954.txt
#   inflating: /content/1900s/news_1902_676155.txt
#   inflating: /content/1900s/news_1904_676758.txt
#   inflating: /content/1900s/fic_1904_14514.txt
#   inflating: /content/1900s/fic_1908_5519.txt
#   inflating: /content/1900s/mag_1907_486893.txt
#   inflating: /content/1900s/news_1901_675718.txt
#   inflating: /content/1900s/mag_1907_457562.txt
#   inflating: /content/1900s/news_1907_677716.txt
#   inflating: /content/1900s/news_1900_675402.txt
#   inflating: /content/1900s/fic_1900_3070.txt
#   inflating: /content/1900s/news_1904_676823.txt
#   inflating: /content/1900s/news_1906_677430.txt
#   inflating: /content/1900s/news_1908_677950.txt
#   inflating: /content/1900s/news_1906_677356.txt
#   inflating: /content/1900s/mag_1905_474252.txt
#   inflating: /content/1900s/news_1906_677342.txt
#   inflating: /content/1900s/news_1904_676604.txt
#   inflating: /content/1900s/mag_1900_473114.txt
#   inflating: /content/1900s/news_1902_676009.txt
#   inflating: /content/1900s/news_1903_676461.txt
#   inflating: /content/1900s/news_1903_676475.txt
#   inflating: /content/1900s/news_1903_676313.txt
#   inflating: /content/1900s/mag_1900_430005.txt
#   inflating: /content/1900s/news_1908_677987.txt
#   inflating: /content/1900s/mag_1900_430011.txt
#   inflating: /content/1900s/news_1905_676913.txt
#   inflating: /content/1900s/mag_1905_430148.txt
#   inflating: /content/1900s/mag_1908_474669.txt
#   inflating: /content/1900s/news_1905_781425.txt
#   inflating: /content/1900s/fic_1909_4405.txt
#   inflating: /content/1900s/mag_1901_485981.txt
#   inflating: /content/1900s/news_1907_677514.txt
#   inflating: /content/1900s/mag_1905_474050.txt
#   inflating: /content/1900s/mag_1905_430174.txt
#   inflating: /content/1900s/mag_1905_430160.txt
#   inflating: /content/1900s/mag_1903_439749.txt
#   inflating: /content/1900s/news_1902_675931.txt
#   inflating: /content/1900s/news_1908_678120.txt
#   inflating: /content/1900s/news_1908_678134.txt
#   inflating: /content/1900s/news_1909_678574.txt
#   inflating: /content/1900s/fic_1900_14395.txt
#   inflating: /content/1900s/fic_1907_14332.txt
#   inflating: /content/1900s/mag_1905_474087.txt
#   inflating: /content/1900s/news_1902_676223.txt
#   inflating: /content/1900s/news_1906_677183.txt
#   inflating: /content/1900s/mag_1905_439187.txt
#   inflating: /content/1900s/mag_1907_474622.txt
#   inflating: /content/1900s/news_1902_676235.txt
#   inflating: /content/1900s/news_1906_677195.txt
#   inflating: /content/1900s/news_1906_677181.txt
#   inflating: /content/1900s/news_1902_676221.txt
#   inflating: /content/1900s/mag_1905_430189.txt
#   inflating: /content/1900s/news_1908_678122.txt
#   inflating: /content/1900s/mag_1909_486730.txt
#   inflating: /content/1900s/news_1902_676209.txt
#   inflating: /content/1900s/news_1905_781382.txt
#   inflating: /content/1900s/mag_1905_430176.txt
#   inflating: /content/1900s/news_1905_676939.txt
#   inflating: /content/1900s/mag_1905_430162.txt
#   inflating: /content/1900s/mag_1901_486508.txt
#   inflating: /content/1900s/news_1905_676911.txt
#   inflating: /content/1900s/news_1907_677502.txt
#   inflating: /content/1900s/fic_1907_2321.txt
#   inflating: /content/1900s/mag_1901_440407.txt
#   inflating: /content/1900s/fic_1903_468.txt
#   inflating: /content/1900s/news_1906_677397.txt
#   inflating: /content/1900s/mag_1900_430007.txt
#   inflating: /content/1900s/news_1908_678308.txt
#   inflating: /content/1900s/news_1900_675399.txt
#   inflating: /content/1900s/mag_1900_430013.txt
#   inflating: /content/1900s/fic_1906_2876.txt
#   inflating: /content/1900s/news_1902_676023.txt
#   inflating: /content/1900s/news_1908_677985.txt
#   inflating: /content/1900s/nf_1906_773677.txt
#   inflating: /content/1900s/news_1901_675901.txt
#   inflating: /content/1900s/news_1904_676612.txt
#   inflating: /content/1900s/news_1903_676311.txt
#   inflating: /content/1900s/mag_1902_439860.txt
#   inflating: /content/1900s/mag_1909_474968.txt
#   inflating: /content/1900s/news_1903_676477.txt
#   inflating: /content/1900s/news_1900_675428.txt
#   inflating: /content/1900s/news_1906_677432.txt
#   inflating: /content/1900s/news_1901_675726.txt
#   inflating: /content/1900s/fic_1903_14360.txt
#   inflating: /content/1900s/news_1903_676488.txt
#   inflating: /content/1900s/news_1906_677368.txt
#   inflating: /content/1900s/news_1907_677700.txt
#   inflating: /content/1900s/news_1900_675414.txt
#   inflating: /content/1900s/news_1909_781448.txt
#   inflating: /content/1900s/news_1907_677714.txt
#   inflating: /content/1900s/news_1907_677853.txt
#   inflating: /content/1900s/mag_1907_430316.txt
#   inflating: /content/1900s/news_1909_678600.txt
#   inflating: /content/1900s/news_1903_676517.txt
#   inflating: /content/1900s/mag_1904_486525.txt
#   inflating: /content/1900s/news_1901_675875.txt
#   inflating: /content/1900s/news_1905_677004.txt
#   inflating: /content/1900s/mag_1903_486740.txt
#   inflating: /content/1900s/news_1904_676772.txt
#   inflating: /content/1900s/news_1905_677010.txt
#   inflating: /content/1900s/mag_1908_430388.txt
#   inflating: /content/1900s/mag_1908_430405.txt
#   inflating: /content/1900s/news_1902_676180.txt
#   inflating: /content/1900s/mag_1902_430065.txt
#   inflating: /content/1900s/mag_1905_430200.txt
#   inflating: /content/1900s/mag_1908_430363.txt
#   inflating: /content/1900s/news_1901_675652.txt
#   inflating: /content/1900s/mag_1908_430377.txt
#   inflating: /content/1900s/mag_1905_430214.txt
#   inflating: /content/1900s/mag_1902_430071.txt
#   inflating: /content/1900s/news_1900_675548.txt
#   inflating: /content/1900s/news_1907_677674.txt
#   inflating: /content/1900s/mag_1902_430059.txt
#   inflating: /content/1900s/mag_1904_430132.txt
#   inflating: /content/1900s/mag_1900_485051.txt
#   inflating: /content/1900s/mag_1904_474016.txt
#   inflating: /content/1900s/news_1908_678283.txt
#   inflating: /content/1900s/mag_1905_430228.txt
#   inflating: /content/1900s/mag_1905_486824.txt
#   inflating: /content/1900s/news_1907_677660.txt
#   inflating: /content/1900s/mag_1904_430126.txt
#   inflating: /content/1900s/news_1906_677208.txt
#   inflating: /content/1900s/news_1909_678402.txt
#   inflating: /content/1900s/fic_1902_1232.txt
#   inflating: /content/1900s/mag_1906_438646.txt
#   inflating: /content/1900s/news_1907_677489.txt
#   inflating: /content/1900s/mag_1901_430043.txt
#   inflating: /content/1900s/news_1908_678056.txt
#   inflating: /content/1900s/mag_1906_474302.txt
#   inflating: /content/1900s/news_1909_678358.txt
#   inflating: /content/1900s/news_1908_678042.txt
#   inflating: /content/1900s/news_1907_781445.txt
#   inflating: /content/1900s/mag_1908_474723.txt
#   inflating: /content/1900s/mag_1903_473722.txt
#   inflating: /content/1900s/news_1908_678095.txt
#   inflating: /content/1900s/news_1902_781044.txt
#   inflating: /content/1900s/news_1907_677476.txt
#   inflating: /content/1900s/news_1907_677463.txt
#   inflating: /content/1900s/news_1908_678094.txt
#   inflating: /content/1900s/fic_1900_14209.txt
#   inflating: /content/1900s/news_1907_677477.txt
#   inflating: /content/1900s/mag_1905_474133.txt
#   inflating: /content/1900s/mag_1903_473737.txt
#   inflating: /content/1900s/fic_1909_3547.txt
#   inflating: /content/1900s/fic_1908_1422.txt
#   inflating: /content/1900s/nf_1903_773883.txt
#   inflating: /content/1900s/news_1903_781377.txt
#   inflating: /content/1900s/mag_1900_440654.txt
#   inflating: /content/1900s/news_1908_678043.txt
#   inflating: /content/1900s/news_1907_781444.txt
#   inflating: /content/1900s/mag_1901_430042.txt
#   inflating: /content/1900s/news_1909_678359.txt
#   inflating: /content/1900s/mag_1900_440683.txt
#   inflating: /content/1900s/mag_1902_486665.txt
#   inflating: /content/1900s/news_1909_678417.txt
#   inflating: /content/1900s/mag_1909_465290.txt
#   inflating: /content/1900s/mag_1902_440030.txt
#   inflating: /content/1900s/news_1909_678403.txt
#   inflating: /content/1900s/news_1909_678365.txt
#   inflating: /content/1900s/mag_1905_486825.txt
#   inflating: /content/1900s/fic_1909_2467.txt
#   inflating: /content/1900s/mag_1905_430229.txt
#   inflating: /content/1900s/mag_1904_430127.txt
#   inflating: /content/1900s/news_1906_677209.txt
#   inflating: /content/1900s/news_1900_675575.txt
#   inflating: /content/1900s/mag_1900_485044.txt
#   inflating: /content/1900s/fic_1900_1076.txt
#   inflating: /content/1900s/mag_1904_430133.txt
#   inflating: /content/1900s/mag_1902_430058.txt
#   inflating: /content/1900s/news_1907_677675.txt
#   inflating: /content/1900s/mag_1905_486831.txt
#   inflating: /content/1900s/mag_1905_430215.txt
#   inflating: /content/1900s/mag_1907_474582.txt
#   inflating: /content/1900s/news_1904_676798.txt
#   inflating: /content/1900s/mag_1905_486819.txt
#   inflating: /content/1900s/mag_1908_430376.txt
#   inflating: /content/1900s/news_1902_676195.txt
#   inflating: /content/1900s/fic_1909_4994.txt
#   inflating: /content/1900s/news_1906_677235.txt
#   inflating: /content/1900s/news_1907_677885.txt
#   inflating: /content/1900s/mag_1902_430070.txt
#   inflating: /content/1900s/mag_1902_430064.txt
#   inflating: /content/1900s/mag_1908_430404.txt
#   inflating: /content/1900s/mag_1909_437703.txt
#   inflating: /content/1900s/mag_1905_430201.txt
#   inflating: /content/1900s/mag_1908_430389.txt
#   inflating: /content/1900s/news_1905_677011.txt
#   inflating: /content/1900s/fic_1902_2504.txt
#   inflating: /content/1900s/news_1903_676516.txt
#   inflating: /content/1900s/news_1905_677005.txt
#   inflating: /content/1900s/news_1901_675874.txt
#   inflating: /content/1900s/mag_1903_486741.txt
#   inflating: /content/1900s/news_1909_678615.txt
#   inflating: /content/1900s/news_1902_676156.txt
#   inflating: /content/1900s/news_1901_675848.txt
#   inflating: /content/1900s/mag_1907_430317.txt
#   inflating: /content/1900s/news_1907_781097.txt
#   inflating: /content/1900s/news_1909_781449.txt
#   inflating: /content/1900s/news_1900_675415.txt
#   inflating: /content/1900s/news_1907_677701.txt
#   inflating: /content/1900s/news_1906_677369.txt
#   inflating: /content/1900s/news_1906_677427.txt
#   inflating: /content/1900s/news_1904_676834.txt
#   inflating: /content/1900s/news_1907_677729.txt
#   inflating: /content/1900s/news_1908_677947.txt
#   inflating: /content/1900s/news_1906_677341.txt
#   inflating: /content/1900s/fic_1903_14361.txt
#   inflating: /content/1900s/news_1908_677953.txt
#   inflating: /content/1900s/news_1900_675429.txt
#   inflating: /content/1900s/news_1904_676820.txt
#   inflating: /content/1900s/news_1903_676310.txt
#   inflating: /content/1900s/news_1904_676613.txt
#   inflating: /content/1900s/news_1903_676476.txt
#   inflating: /content/1900s/mag_1904_486450.txt
#   inflating: /content/1900s/news_1905_677159.txt
#   inflating: /content/1900s/mag_1901_473231.txt
#   inflating: /content/1900s/news_1908_678309.txt
#   inflating: /content/1900s/news_1908_677984.txt
#   inflating: /content/1900s/fic_1909_813.txt
#   inflating: /content/1900s/news_1902_676022.txt
#   inflating: /content/1900s/mag_1900_430012.txt
#   inflating: /content/1900s/news_1902_676036.txt
#   inflating: /content/1900s/mag_1900_430006.txt
#   inflating: /content/1900s/news_1906_677396.txt
#   inflating: /content/1900s/news_1908_677990.txt
#   inflating: /content/1900s/fic_1904_830.txt
#   inflating: /content/1900s/news_1903_676338.txt
#   inflating: /content/1900s/nf_1909_773415.txt
#   inflating: /content/1900s/news_1905_676904.txt
#   inflating: /content/1900s/news_1905_781426.txt
#   inflating: /content/1900s/mag_1905_439147.txt
#   inflating: /content/1900s/mag_1901_486509.txt
#   inflating: /content/1900s/mag_1905_430163.txt
#   inflating: /content/1900s/mag_1905_430177.txt
#   inflating: /content/1900s/mag_1901_440348.txt
#   inflating: /content/1900s/fic_1906_3764.txt
#   inflating: /content/1900s/news_1905_781383.txt
#   inflating: /content/1900s/news_1908_678137.txt
#   inflating: /content/1900s/news_1908_678123.txt
#   inflating: /content/1900s/mag_1906_474277.txt
#   inflating: /content/1900s/mag_1905_430188.txt
#   inflating: /content/1900s/fic_1906_4792.txt
#   inflating: /content/1900s/mag_1907_474637.txt
#   inflating: /content/1900s/nf_1907_773752.txt
#   inflating: /content/1900s/news_1909_678577.txt
#   inflating: /content/1900s/fic_1908_5081.txt
#   inflating: /content/1900s/news_1906_677194.txt
#   inflating: /content/1900s/news_1902_676234.txt
#   inflating: /content/1900s/mag_1906_438733.txt

# %% [markdown]
# You can replace the dataset above with any dataset hosted on [the hub](https://huggingface.co/datasets) or use your own files. Just uncomment the following cell and replace the paths with values that will lead to your files:

# %%
from os import listdir
from os.path import isfile, join
mypath = "/content/1900s"
# mypath = "coha/COHA text/1900s"
files = [mypath + "/" + f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
len(files)
# Out:
# 2981

# %%
import random
random.shuffle(files)
# Split into 80% train and 20% validation
split_index = int(0.8 * len(files))
train_files = files[:split_index]
val_files = files[split_index:]

# %%
from datasets import load_dataset
datasets = load_dataset('text', data_files={'train': train_files, "validation": val_files})
# Out:
# Resolving data files:   0%|          | 0/2384 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/597 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# You can also load datasets from a csv or a JSON file, see the [full documentation](https://huggingface.co/docs/datasets/loading_datasets.html#from-local-files) for more information.

# %% [markdown]
# To access an actual element, you need to select a split first, then give an index:

# %%
datasets["train"][0]
# Out:
# {'text': '@@473082'}

# %% [markdown]
# To get a sense of what the data looks like, the following function will show some examples picked randomly in the dataset.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)

    df = pd.DataFrame(dataset[picks])
    for column, typ in dataset.features.items():
        if isinstance(typ, ClassLabel):
            df[column] = df[column].transform(lambda i: typ.names[i])
    display(HTML(df.to_html()))

# %%
show_random_elements(datasets["train"])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>|p1177  SHORTLY before leaving for Europe Mr. Carnegie made a speech at Northampton , Mass. , in which he expressed his unqualified approval of dancing , on the grounds that we should make this life as happy as we can , and that it does much for children in improving their manners and bearing . At about the same time there was a convention of physical culture experts at the Teachers ' College , Columbia University , at which Dr. Sargent , of Harvard , spoke on " Useful Dancing from the Physical Training Standpoint , " and Elizabeth Burchenal explained how grace of carriage and posture are acquired by training in dancing . In his recent erudite volumes on " Adolescence " President G. Stanley Hall , of Clark University , makes a strong plea for the dance : We have in the dance of the modern ballroom only a degenerate relict , with at best but a very insignificant culture value , and too often stained with bad associations . This is most unfortunate for youth , and for their sake a work of rescue and @ @ @ @ @ @ @ @ @ @ not excepting even music , the completest language of the emotions and can be made one of the best schools of sentiment and even will , inoculating good states of mind and exorcising bad ones as few other agencies have power to do . " Evidently a tendency in favor of a renaissance of the art of dancing is in the air . What are its chances of success ? Has dancing a future ? It can not be denied that at social functions it does not play as important a role as it used to . Girls still seem to be eager to dance , but dancing men ( striplings excepted ) are becoming more and more scarce . Yet it does not follow from this that the situation is hopeless . In all probability the tide might be turned if dances were held before midnight instead of after midnight . Most American men are hard workers , who can not afford to burn the candle at both ends . The words " Dancing from nine to twelve " on cards of invitation would doubtless bring many desirable men back @ @ @ @ @ @ @ @ @ @ to be wished , for diverse reasons . Undoubtedly women and men , girls and boys , in American cities do not get enough exercise . Time is short and transportation facilities are so abundant and cheap that very few do as much walking as consideration for their health demands . Nearly every afternoon I walk in Central Park , and every time I wonder at the lamentably small number of persons who frequent this beautiful patch of country in the midst of Manhattan for exercise and refreshment . Early dances , rendered attractive by beautiful women , bright lights , good music , simple suppers , opportunities for conversation and parlor games for variety , would doubtless attract many men who , in addition to all these things , would , like their partners , enjoy the hygienic advantages of one of the most efficient forms of muscular exercise . Another consideration in favor of a revival of the social dance is that it affords the best opportunities for courtship . Doubtless the increase in the number of bachelors and old maids is partly a result of the decline of @ @ @ @ @ @ @ @ @ @ easily made . The fact that at certain dancing schools and balls undesirable acquaintances may be made has caused many worthy parents to taboo dancing entirely , which is unnecessary , for if these parents will give the matter the supervision it calls for mistakes are no more likely to occur in the ballroom than at other social gatherings . If dancing is to have a future it must be made suitable for others besides the very young , to whom it now appeals almost exclusively . Before the nineteenth century most dances were slow and stately . The young folks not being allowed to meet in the days of strict chaperonage , the art of dancing was in/ trusted to the matured and married folk , to whose needs the stately gavottes , minuets , sarabandes , etc. , were well adapted . For those under thirty the rapid modern waltz , polka and gallop are no doubt best suited ; but why ...

# %% [markdown]
# As we can see, some of the texts are a full paragraph of a Wikipedia article while others are just titles or empty lines.

# %% [markdown]
# ## Causal Language modeling

# %% [markdown]
# For causal language modeling (CLM) we are going to take all the texts in our dataset and concatenate them after they are tokenized. Then we will split them in examples of a certain sequence length. This way the model will receive chunks of contiguous text that may look like:
# ```
# part of text 1
# ```
# or
# ```
# end of text 1 [BOS_TOKEN] beginning of text 2
# ```
# depending on whether they span over several of the original texts in the dataset or not. The labels will be the same as the inputs, shifted to the left.
#
# We will use the [`distilgpt2`](https://huggingface.co/distilgpt2) model for this example. You can pick any of the checkpoints listed [here](https://huggingface.co/models?filter=causal-lm) instead:

# %%
model_checkpoint = "distilgpt2"

# %% [markdown]
# To tokenize all our texts with the same vocabulary that was used when training the model, we have to download a pretrained tokenizer. This is all done by the `AutoTokenizer` class:

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# We can now call the tokenizer on all our texts. This is very simple, using the [`map`](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.map) method from the Datasets library. First we define a function that call the tokenizer on our texts:

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"])

# %% [markdown]
# Then we apply it to all the splits in our `datasets` object, using `batched=True` and 4 processes to speed up the preprocessing. We won't need the `text` column afterward, so we discard it.

# %%
tokenized_datasets = datasets.map(tokenize_function, batched=True, num_proc=4, remove_columns=["text"])

# %% [markdown]
# If we now look at an element of our datasets, we will see the text have been replaced by the `input_ids` the model will need:

# %%
tokenized_datasets["train"][1]
# Out:
# {'input_ids': [101, 102], 'token_type_ids': [0, 0], 'attention_mask': [1, 1]}

# %% [markdown]
# Now for the harder part: we need to concatenate all our texts together then split the result in small chunks of a certain `block_size`. To do this, we will use the `map` method again, with the option `batched=True`. This option actually lets us change the number of examples in the datasets by returning a different number of examples than we got. This way, we can create our new samples from a batch of examples.
#
# First, we grab the maximum length our model was pretrained with. This might be a big too big to fit in your GPU RAM, so here we take a bit less at just 128.

# %%
# block_size = tokenizer.model_max_length
block_size = 128

# %% [markdown]
# Then we write the preprocessing function that will group our texts:

# %%
def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
        # customize this part to your needs.
    total_length = (total_length // block_size) * block_size
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

# %% [markdown]
# First note that we duplicate the inputs for our labels. This is because the model of the 🤗 Transformers library apply the shifting to the right, so we don't need to do it manually.
#
# Also note that by default, the `map` method will send a batch of 1,000 examples to be treated by the preprocessing function. So here, we will drop the remainder to make the concatenated tokenized texts a multiple of `block_size` every 1,000 examples. You can adjust this behavior by passing a higher batch size (which will also be processed slower). You can also speed-up the preprocessing by using multiprocessing:

# %%
lm_datasets = tokenized_datasets.map(
    group_texts,
    batched=True,
    batch_size=1000,
    num_proc=4,
)
# Out:
# Map (num_proc=4):   0%|          | 0/8943 [00:00<?, ? examples/s]

# %% [markdown]
# And we can check our datasets have changed: now the samples contain chunks of `block_size` contiguous tokens, potentially spanning over several of our original texts.

# %%
tokenizer.decode(lm_datasets["train"][1]["input_ids"])
# Out:
# '##kimos. they are copper i colored, and are seven, eight, and even nine feet tall. in features they resemble the american indians. " these strange people, " said capt. jensen, " represented to the eskimos a traditional, almost legendary tribe of giants, stories of which had been handed down to them until they regarded the race as mythical. they can not speak the language of the\'eskimos. and could only make known by signs that they had been driven from @ @ @ @ @ @ @ @ @ @ weather. " had a double eruption. water main burst and explosion resulted from leaking gas pipe.'

# %% [markdown]
# Now that the data has been cleaned, we're ready to instantiate our `Trainer`. We will a model:

# %%
from transformers import AutoModelForCausalLM
model = AutoModelForCausalLM.from_pretrained(model_checkpoint)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`

# %% [markdown]
# And some `TrainingArguments`:

# %%
from transformers import Trainer, TrainingArguments

# %%
model_name = model_checkpoint.split("/")[-1]
training_args = TrainingArguments(
    f"{model_name}-finetuned-coha-1900s",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    push_to_hub=True,
)

# %% [markdown]
# The last argument to setup everything so we can push the model to the [Hub](https://huggingface.co/models) regularly during training. Remove it if you didn't follow the installation steps at the top of the notebook. If you want to save your model locally in a name that is different than the name of the repository it will be pushed, or if you want to push your model under an organization and not your name space, use the `hub_model_id` argument to set the repo name (it needs to be the full name, including your namespace: for instance `"sgugger/gpt-finetuned-wikitext2"` or `"huggingface/gpt-finetuned-wikitext2"`).

# %% [markdown]
# We pass along all of those to the `Trainer` class:

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_datasets["train"],
)

# %% [markdown]
# And we can train our model:

# %%
trainer.train()

# %% [markdown]
# Once the training is completed, we can evaluate our model and get its perplexity on the validation set like this:

# %%
import math
eval_results = trainer.evaluate()
print(f"Perplexity: {math.exp(eval_results['eval_loss']):.2f}")
# Out:
# Perplexity: 38.17

# %% [markdown]
# You can now upload the result of the training to the Hub, just execute this instruction:

# %%
trainer.push_to_hub()

# %% [markdown]
# You can now share this model with all your friends, family, favorite pets: they can all load it with the identifier `"your-username/the-name-you-picked"` so for instance:
#
# ```python
# from transformers import AutoModelForCausalLM
#
# model = AutoModelForCausalLM.from_pretrained("sgugger/my-awesome-model")
# ```

# %% [markdown]
# ## Masked language modeling

# %% [markdown]
# For masked language modeling (MLM) we are going to use the same preprocessing as before for our dataset with one additional step: we will randomly mask some tokens (by replacing them by `[MASK]`) and the labels will be adjusted to only include the masked tokens (we don't have to predict the non-masked tokens).
#
# We will use the [`distilroberta-base`](https://huggingface.co/distilroberta-base) model for this example. You can pick any of the checkpoints listed [here](https://huggingface.co/models?filter=masked-lm) instead:

# %%
model_checkpoint = "bert-base-uncased"

# %% [markdown]
# We can apply the same tokenization function as before, we just need to update our tokenizer to use the checkpoint we just picked:

# %%
from transformers import AutoTokenizer

def tokenize_function(examples):
    return tokenizer(examples["text"])

def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
        # customize this part to your needs.
    total_length = (total_length // block_size) * block_size
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

model_checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)

tokenized_datasets = datasets.map(tokenize_function, batched=True, num_proc=4, remove_columns=["text"])
# block_size = tokenizer.model_max_length
block_size = 128
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Map (num_proc=4):   0%|          | 0/7152 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (6416 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2659 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (3608 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2950 > 512). Running this sequence through the model will result in indexing errors
# Map (num_proc=4):   0%|          | 0/1791 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3291 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (3117 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2198 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (655 > 512). Running this sequence through the model will result in indexing errors

# %% [markdown]
# And like before, we group texts together and chunk them in samples of length `block_size`. You can skip that step if your dataset is composed of individual sentences.

# %%
lm_datasets = tokenized_datasets.map(
    group_texts,
    batched=True,
    batch_size=1000,
    num_proc=4,
)
# Out:
# Map (num_proc=4):   0%|          | 0/7152 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/1791 [00:00<?, ? examples/s]

# %% [markdown]
# The rest is very similar to what we had, with two exceptions. First we use a model suitable for masked LM:

# %%
from transformers import AutoModelForMaskedLM
model = AutoModelForMaskedLM.from_pretrained(model_checkpoint)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# We redefine our `TrainingArguments`:

# %%
from transformers import Trainer, TrainingArguments
model_name = model_checkpoint.split("/")[-1]
training_args = TrainingArguments(
    f"{model_name}-finetuned-coha-2000s",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    push_to_hub=True,
)

# %% [markdown]
# Like before, the last argument to setup everything so we can push the model to the [Hub](https://huggingface.co/models) regularly during training. Remove it if you didn't follow the installation steps at the top of the notebook. If you want to save your model locally in a name that is different than the name of the repository it will be pushed, or if you want to push your model under an organization and not your name space, use the `hub_model_id` argument to set the repo name (it needs to be the full name, including your namespace: for instance `"sgugger/bert-finetuned-wikitext2"` or `"huggingface/bert-finetuned-wikitext2"`).

# %% [markdown]
# Finally, we use a special `data_collator`. The `data_collator` is a function that is responsible of taking the samples and batching them in tensors. In the previous example, we had nothing special to do, so we just used the default for this argument. Here we want to do the random-masking. We could do it as a pre-processing step (like the tokenization) but then the tokens would always be masked the same way at each epoch. By doing this step inside the `data_collator`, we ensure this random masking is done in a new way each time we go over the data.
#
# To do this masking for us, the library provides a `DataCollatorForLanguageModeling`. We can adjust the probability of the masking:

# %%
from transformers import DataCollatorForLanguageModeling
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)

# %%
# Freeze all layers except the last layer
for name, param in model.named_parameters():
    if '11' not in name:
        param.requires_grad = False

# %%
for name, param in model.named_parameters():
    print(name)

# %%
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Number of trainable parameters: {trainable_params}")
# Out:
# Number of trainable parameters: 7087872

# %% [markdown]
# Then we just have to pass everything to `Trainer` and begin training:

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_datasets["train"],
    eval_dataset=lm_datasets["validation"],
    data_collator=data_collator,
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='66657' max='66657' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [66657/66657 2:33:56, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.767100</td>
#       <td>2.589880</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.709900</td>
#       <td>2.550447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.727100</td>
#       <td>2.549809</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=66657, training_loss=2.7745863100711126, metrics={'train_runtime': 9238.6676, 'train_samples_per_second': 57.72, 'train_steps_per_second': 7.215, 'total_flos': 3.50886890100096e+16, 'train_loss': 2.7745863100711126, 'epoch': 3.0})

# %% [markdown]
# Like before, we can evaluate our model on the validation set. The perplexity is much lower than for the CLM objective because for the MLM objective, we only have to make predictions for the masked tokens (which represent 15% of the total here) while having access to the rest of the tokens. It's thus an easier task for the model.

# %%
import math
eval_results = trainer.evaluate()
print(f"Perplexity: {math.exp(eval_results['eval_loss']):.2f}")
# Out:
#     <div>
#
#       <progress value='10338' max='5169' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5169/5169 14:17]
#     </div>
# Perplexity: 12.78

# %% [markdown]
# You can now upload the result of the training to the Hub, just execute this instruction:

# %%
trainer.push_to_hub()
# Out:
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# events.out.tfevents.1706044338.de4647f5666f.267.0:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# events.out.tfevents.1706055095.de4647f5666f.267.1:   0%|          | 0.00/640 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/sally9805/bert-base-uncased-finetuned-coha-1900s/commit/c56a6c47cd8dc7b59f5ba4e5600557351cb3d36f', commit_message='End of training', commit_description='', oid='c56a6c47cd8dc7b59f5ba4e5600557351cb3d36f', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# You can now share this model with all your friends, family, favorite pets: they can all load it with the identifier `"your-username/the-name-you-picked"` so for instance:
#
# ```python
# from transformers import AutoModelForMaskedLM
#
# model = AutoModelForMaskedLM.from_pretrained("sgugger/my-awesome-model")
# ```

# %%
from transformers import AutoModelForMaskedLM

model = AutoModelForMaskedLM.from_pretrained("sally9805/bert-base-uncased-finetuned-coha-1900s")

tokenizer = AutoTokenizer.from_pretrained("sally9805/bert-base-uncased-finetuned-coha-1900s", use_fast=True)
# Out:
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-34-b8955ead7b8e> in <cell line: 5>()
#       3 model = AutoModelForMaskedLM.from_pretrained("sally9805/bert-base-uncased-finetuned-coha-1900s")
#       4
# ----> 5 tokenizer = AutoTokenizer.from_pretrained("sally9805/bert-base-uncased-finetuned-coha-1900s", use_fast=True)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     830             tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#     831             if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 832                 return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     833             else:
#     834                 if tokenizer_class_py is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, *init_inputs, **kwargs)
#    2011
#    2012         if all(full_file_name is None for full_file_name in resolved_vocab_files.values()):
# -> 2013             raise EnvironmentError(
#    2014                 f"Can't load tokenizer for '{pretrained_model_name_or_path}'. If you were trying to load it from "
#    2015                 "'https://huggingface.co/models', make sure you don't have a local directory with the same name. "
#
# OSError: Can't load tokenizer for 'sally9805/bert-base-uncased-finetuned-coha-1900s'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'sally9805/bert-base-uncased-finetuned-coha-1900s' is the correct path to a directory containing all relevant files for a BertTokenizerFast tokenizer.
